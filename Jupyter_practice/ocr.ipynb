# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40, 50, 60, 89, 10, 31, 45, 78, 98, 48, 37, 56, 19, 39, 45, 67, 54, 32, 45, 67, 83]
y = [13, 45, 23, 34, 96, 76, 12, 34, 12, 56, 87, 45, 43, 56, 78, 23, 45, 87, 43, 45, 87, 34, 89, 34]

plt.title('Sample Neural Activity Graph')
plt.bar(x, y, color='dodgerblue', width=5)
plt.show()
